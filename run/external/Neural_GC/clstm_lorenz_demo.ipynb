# %% [markdown]
# # cLSTM Lorenz-96 Demo
# - In this notebook, we train a cLSTM model on data simulated from a Lorenz-96 system

# %%
import os
os.chdir("/project/lcd_v2")
import sys
sys.path.append('/project/lcd_v2/run')
import torch
import numpy as np
import matplotlib.pyplot as plt
from external.Neural_GC.synthetic import simulate_lorenz_96
from external.Neural_GC.models.clstm import cLSTM, train_model_ista

# %%
# For GPU acceleration
device = torch.device('cuda')

# %%
# Simulate data
X_np, GC = simulate_lorenz_96(p=10, F=10, T=1000)
X = torch.tensor(X_np[np.newaxis], dtype=torch.float32, device=device)

# %%
X.shape
# Out:
# torch.Size([1, 1000, 10])

# %%
# Plot data
fig, axarr = plt.subplots(1, 2, figsize=(16, 5))
axarr[0].plot(X_np)
axarr[0].set_xlabel('T')
axarr[0].set_title('Entire time series')
axarr[1].plot(X_np[:50])
axarr[1].set_xlabel('T')
axarr[1].set_title('First 50 time points')
plt.tight_layout()
plt.show()

# %%
# Set up model
clstm = cLSTM(X.shape[-1], hidden=100).cuda(device=device)

# %%
# Train with ISTA
train_loss_list = train_model_ista(
    clstm, X, context=10, lam=10.0, lam_ridge=1e-2, lr=1e-3, max_iter=20000,
    check_every=50)
# Out:
# ----------Iter = 50----------
# Loss = 86.022339
# Variable usage = 100.00%
# ----------Iter = 100----------
# Loss = 37.665813
# Variable usage = 100.00%
# ----------Iter = 150----------
# Loss = 21.818947
# Variable usage = 23.00%
# ----------Iter = 200----------
# Loss = 20.417952
# Variable usage = 17.00%
# ----------Iter = 250----------
# Loss = 19.593435
# Variable usage = 15.00%
# ----------Iter = 300----------
# Loss = 19.035263
# Variable usage = 14.00%
# ----------Iter = 350----------
# Loss = 18.623486
# Variable usage = 14.00%
# ----------Iter = 400----------
# Loss = 18.295462
# Variable usage = 17.00%
# ----------Iter = 450----------
# Loss = 18.012493
# Variable usage = 20.00%
# ----------Iter = 500----------
# Loss = 17.752266
# Variable usage = 24.00%
# ----------Iter = 550----------
# Loss = 17.504141
# Variable usage = 27.00%
# ----------Iter = 600----------
# Loss = 17.263535
# Variable usage = 27.00%
# ----------Iter = 650----------
# Loss = 17.029465
# Variable usage = 29.00%
# ----------Iter = 700----------
# Loss = 16.801672
# Variable usage = 31.00%
# ----------Iter = 750----------
# Loss = 16.580091
# Variable usage = 32.00%
# ----------Iter = 800----------
# Loss = 16.364727
# Variable usage = 33.00%
# ----------Iter = 850----------
# Loss = 16.155535
# Variable usage = 34.00%
# ----------Iter = 900----------
# Loss = 15.952365
# Variable usage = 34.00%
# ----------Iter = 950----------
# Loss = 15.755142
# Variable usage = 35.00%
# ----------Iter = 1000----------
# Loss = 15.563690
# Variable usage = 35.00%
# ----------Iter = 1050----------
# Loss = 15.377841
# Variable usage = 35.00%
# ----------Iter = 1100----------
# Loss = 15.197492
# Variable usage = 35.00%
# ----------Iter = 1150----------
# Loss = 15.022540
# Variable usage = 35.00%
# ----------Iter = 1200----------
# Loss = 14.852892
# Variable usage = 35.00%
# ----------Iter = 1250----------
# Loss = 14.688453
# Variable usage = 35.00%
# ----------Iter = 1300----------
# Loss = 14.529129
# Variable usage = 35.00%
# ----------Iter = 1350----------
# Loss = 14.374826
# Variable usage = 35.00%
# ----------Iter = 1400----------
# Loss = 14.225451
# Variable usage = 35.00%
# ----------Iter = 1450----------
# Loss = 14.080896
# Variable usage = 36.00%
# ----------Iter = 1500----------
# Loss = 13.941052
# Variable usage = 36.00%
# ----------Iter = 1550----------
# Loss = 13.805799
# Variable usage = 36.00%
# ----------Iter = 1600----------
# Loss = 13.675011
# Variable usage = 36.00%
# ----------Iter = 1650----------
# Loss = 13.548549
# Variable usage = 36.00%
# ----------Iter = 1700----------
# Loss = 13.426276
# Variable usage = 36.00%
# ----------Iter = 1750----------
# Loss = 13.308042
# Variable usage = 36.00%
# ----------Iter = 1800----------
# Loss = 13.193687
# Variable usage = 36.00%
# ----------Iter = 1850----------
# Loss = 13.083063
# Variable usage = 36.00%
# ----------Iter = 1900----------
# Loss = 12.976006
# Variable usage = 36.00%
# ----------Iter = 1950----------
# Loss = 12.872362
# Variable usage = 36.00%
# ----------Iter = 2000----------
# Loss = 12.771970
# Variable usage = 36.00%
# ----------Iter = 2050----------
# Loss = 12.674677
# Variable usage = 36.00%
# ----------Iter = 2100----------
# Loss = 12.580330
# Variable usage = 36.00%
# ----------Iter = 2150----------
# Loss = 12.488786
# Variable usage = 36.00%
# ----------Iter = 2200----------
# Loss = 12.399901
# Variable usage = 36.00%
# ----------Iter = 2250----------
# Loss = 12.313540
# Variable usage = 36.00%
# ----------Iter = 2300----------
# Loss = 12.229575
# Variable usage = 36.00%
# ----------Iter = 2350----------
# Loss = 12.147880
# Variable usage = 36.00%
# ----------Iter = 2400----------
# Loss = 12.068339
# Variable usage = 36.00%
# ----------Iter = 2450----------
# Loss = 11.990843
# Variable usage = 36.00%
# ----------Iter = 2500----------
# Loss = 11.915286
# Variable usage = 36.00%
# ----------Iter = 2550----------
# Loss = 11.841571
# Variable usage = 36.00%
# ----------Iter = 2600----------
# Loss = 11.769607
# Variable usage = 36.00%
# ----------Iter = 2650----------
# Loss = 11.699306
# Variable usage = 36.00%
# ----------Iter = 2700----------
# Loss = 11.630589
# Variable usage = 36.00%
# ----------Iter = 2750----------
# Loss = 11.563379
# Variable usage = 36.00%
# ----------Iter = 2800----------
# Loss = 11.497607
# Variable usage = 35.00%
# ----------Iter = 2850----------
# Loss = 11.433207
# Variable usage = 35.00%
# ----------Iter = 2900----------
# Loss = 11.370118
# Variable usage = 35.00%
# ----------Iter = 2950----------
# Loss = 11.308283
# Variable usage = 35.00%
# ----------Iter = 3000----------
# Loss = 11.247647
# Variable usage = 35.00%
# ----------Iter = 3050----------
# Loss = 11.188163
# Variable usage = 35.00%
# ----------Iter = 3100----------
# Loss = 11.129782
# Variable usage = 35.00%
# ----------Iter = 3150----------
# Loss = 11.072461
# Variable usage = 35.00%
# ----------Iter = 3200----------
# Loss = 11.016162
# Variable usage = 35.00%
# ----------Iter = 3250----------
# Loss = 10.960846
# Variable usage = 35.00%
# ----------Iter = 3300----------
# Loss = 10.906476
# Variable usage = 35.00%
# ----------Iter = 3350----------
# Loss = 10.853022
# Variable usage = 35.00%
# ----------Iter = 3400----------
# Loss = 10.800448
# Variable usage = 35.00%
# ----------Iter = 3450----------
# Loss = 10.748733
# Variable usage = 35.00%
# ----------Iter = 3500----------
# Loss = 10.697845
# Variable usage = 35.00%
# ----------Iter = 3550----------
# Loss = 10.647758
# Variable usage = 35.00%
# ----------Iter = 3600----------
# Loss = 10.598450
# Variable usage = 35.00%
# ----------Iter = 3650----------
# Loss = 10.549899
# Variable usage = 35.00%
# ----------Iter = 3700----------
# Loss = 10.502085
# Variable usage = 35.00%
# ----------Iter = 3750----------
# Loss = 10.454984
# Variable usage = 35.00%
# ----------Iter = 3800----------
# Loss = 10.408579
# Variable usage = 35.00%
# ----------Iter = 3850----------
# Loss = 10.362855
# Variable usage = 35.00%
# ----------Iter = 3900----------
# Loss = 10.317792
# Variable usage = 35.00%
# ----------Iter = 3950----------
# Loss = 10.273376
# Variable usage = 35.00%
# ----------Iter = 4000----------
# Loss = 10.229593
# Variable usage = 35.00%
# ----------Iter = 4050----------
# Loss = 10.186427
# Variable usage = 35.00%
# ----------Iter = 4100----------
# Loss = 10.143865
# Variable usage = 35.00%
# ----------Iter = 4150----------
# Loss = 10.101892
# Variable usage = 35.00%
# ----------Iter = 4200----------
# Loss = 10.060500
# Variable usage = 35.00%
# ----------Iter = 4250----------
# Loss = 10.019673
# Variable usage = 35.00%
# ----------Iter = 4300----------
# Loss = 9.979403
# Variable usage = 35.00%
# ----------Iter = 4350----------
# Loss = 9.939676
# Variable usage = 35.00%
# ----------Iter = 4400----------
# Loss = 9.900484
# Variable usage = 35.00%
# ----------Iter = 4450----------
# Loss = 9.861816
# Variable usage = 35.00%
# ----------Iter = 4500----------
# Loss = 9.823663
# Variable usage = 35.00%
# ----------Iter = 4550----------
# Loss = 9.786015
# Variable usage = 35.00%
# ----------Iter = 4600----------
# Loss = 9.748863
# Variable usage = 35.00%
# ----------Iter = 4650----------
# Loss = 9.712198
# Variable usage = 35.00%
# ----------Iter = 4700----------
# Loss = 9.676012
# Variable usage = 35.00%
# ----------Iter = 4750----------
# Loss = 9.640296
# Variable usage = 35.00%
# ----------Iter = 4800----------
# Loss = 9.605043
# Variable usage = 35.00%
# ----------Iter = 4850----------
# Loss = 9.570245
# Variable usage = 35.00%
# ----------Iter = 4900----------
# Loss = 9.535893
# Variable usage = 35.00%
# ----------Iter = 4950----------
# Loss = 9.501982
# Variable usage = 35.00%
# ----------Iter = 5000----------
# Loss = 9.468502
# Variable usage = 35.00%
# ----------Iter = 5050----------
# Loss = 9.435448
# Variable usage = 35.00%
# ----------Iter = 5100----------
# Loss = 9.402811
# Variable usage = 35.00%
# ----------Iter = 5150----------
# Loss = 9.370587
# Variable usage = 35.00%
# ----------Iter = 5200----------
# Loss = 9.338767
# Variable usage = 36.00%
# ----------Iter = 5250----------
# Loss = 9.307343
# Variable usage = 36.00%
# ----------Iter = 5300----------
# Loss = 9.276313
# Variable usage = 36.00%
# ----------Iter = 5350----------
# Loss = 9.245666
# Variable usage = 36.00%
# ----------Iter = 5400----------
# Loss = 9.215395
# Variable usage = 36.00%
# ----------Iter = 5450----------
# Loss = 9.185498
# Variable usage = 36.00%
# ----------Iter = 5500----------
# Loss = 9.155967
# Variable usage = 36.00%
# ----------Iter = 5550----------
# Loss = 9.126797
# Variable usage = 36.00%
# ----------Iter = 5600----------
# Loss = 9.097980
# Variable usage = 36.00%
# ----------Iter = 5650----------
# Loss = 9.069514
# Variable usage = 36.00%
# ----------Iter = 5700----------
# Loss = 9.041392
# Variable usage = 36.00%
# ----------Iter = 5750----------
# Loss = 9.013611
# Variable usage = 36.00%
# ----------Iter = 5800----------
# Loss = 8.986162
# Variable usage = 36.00%
# ----------Iter = 5850----------
# Loss = 8.959043
# Variable usage = 36.00%
# ----------Iter = 5900----------
# Loss = 8.932247
# Variable usage = 36.00%
# ----------Iter = 5950----------
# Loss = 8.905772
# Variable usage = 36.00%
# ----------Iter = 6000----------
# Loss = 8.879611
# Variable usage = 36.00%
# ----------Iter = 6050----------
# Loss = 8.853763
# Variable usage = 36.00%
# ----------Iter = 6100----------
# Loss = 8.828220
# Variable usage = 36.00%
# ----------Iter = 6150----------
# Loss = 8.803199
# Variable usage = 36.00%
# ----------Iter = 6200----------
# Loss = 8.881052
# Variable usage = 40.00%
# ----------Iter = 6250----------
# Loss = 8.755698
# Variable usage = 36.00%
# ----------Iter = 6300----------
# Loss = 8.731216
# Variable usage = 36.00%
# ----------Iter = 6350----------
# Loss = 8.707143
# Variable usage = 36.00%
# ----------Iter = 6400----------
# Loss = 8.683360
# Variable usage = 36.00%
# ----------Iter = 6450----------
# Loss = 8.659857
# Variable usage = 36.00%
# ----------Iter = 6500----------
# Loss = 8.636629
# Variable usage = 36.00%
# ----------Iter = 6550----------
# Loss = 8.698031
# Variable usage = 38.00%
# ----------Iter = 6600----------
# Loss = 8.593472
# Variable usage = 36.00%
# ----------Iter = 6650----------
# Loss = 8.570739
# Variable usage = 36.00%
# ----------Iter = 6700----------
# Loss = 8.548556
# Variable usage = 36.00%
# ----------Iter = 6750----------
# Loss = 8.526647
# Variable usage = 36.00%
# ----------Iter = 6800----------
# Loss = 8.504992
# Variable usage = 36.00%
# ----------Iter = 6850----------
# Loss = 8.483747
# Variable usage = 36.00%
# ----------Iter = 6900----------
# Loss = 8.548780
# Variable usage = 38.00%
# ----------Iter = 6950----------
# Loss = 8.443913
# Variable usage = 36.00%
# ----------Iter = 7000----------
# Loss = 8.423137
# Variable usage = 36.00%
# ----------Iter = 7050----------
# Loss = 8.402695
# Variable usage = 37.00%
# ----------Iter = 7100----------
# Loss = 8.642951
# Variable usage = 43.00%
# ----------Iter = 7150----------
# Loss = 8.366942
# Variable usage = 37.00%
# ----------Iter = 7200----------
# Loss = 8.346488
# Variable usage = 37.00%
# ----------Iter = 7250----------
# Loss = 8.380204
# Variable usage = 39.00%
# ----------Iter = 7300----------
# Loss = 8.309392
# Variable usage = 37.00%
# ----------Iter = 7350----------
# Loss = 8.290183
# Variable usage = 37.00%
# ----------Iter = 7400----------
# Loss = 8.271262
# Variable usage = 37.00%
# ----------Iter = 7450----------
# Loss = 8.252563
# Variable usage = 37.00%
# ----------Iter = 7500----------
# Loss = 8.234076
# Variable usage = 38.00%
# ----------Iter = 7550----------
# Loss = 8.221678
# Variable usage = 37.00%
# ----------Iter = 7600----------
# Loss = 8.202126
# Variable usage = 38.00%
# ----------Iter = 7650----------
# Loss = 8.182325
# Variable usage = 38.00%
# ----------Iter = 7700----------
# Loss = 8.164609
# Variable usage = 38.00%
# ----------Iter = 7750----------
# Loss = 8.147130
# Variable usage = 38.00%
# ----------Iter = 7800----------
# Loss = 8.129851
# Variable usage = 38.00%
# ----------Iter = 7850----------
# Loss = 8.112770
# Variable usage = 38.00%
# ----------Iter = 7900----------
# Loss = 8.298536
# Variable usage = 44.00%
# ----------Iter = 7950----------
# Loss = 8.086364
# Variable usage = 38.00%
# ----------Iter = 8000----------
# Loss = 8.068680
# Variable usage = 38.00%
# ----------Iter = 8050----------
# Loss = 8.052192
# Variable usage = 38.00%
# ----------Iter = 8100----------
# Loss = 8.035926
# Variable usage = 38.00%
# ----------Iter = 8150----------
# Loss = 8.019851
# Variable usage = 38.00%
# ----------Iter = 8200----------
# Loss = 8.003957
# Variable usage = 38.00%
# ----------Iter = 8250----------
# Loss = 8.124240
# Variable usage = 41.00%
# ----------Iter = 8300----------
# Loss = 7.976036
# Variable usage = 38.00%
# ----------Iter = 8350----------
# Loss = 7.960584
# Variable usage = 38.00%
# ----------Iter = 8400----------
# Loss = 7.950994
# Variable usage = 39.00%
# ----------Iter = 8450----------
# Loss = 7.932561
# Variable usage = 39.00%
# ----------Iter = 8500----------
# Loss = 7.917564
# Variable usage = 39.00%
# ----------Iter = 8550----------
# Loss = 7.902784
# Variable usage = 39.00%
# ----------Iter = 8600----------
# Loss = 8.300180
# Variable usage = 46.00%
# ----------Iter = 8650----------
# Loss = 7.881904
# Variable usage = 39.00%
# ----------Iter = 8700----------
# Loss = 7.866260
# Variable usage = 39.00%
# ----------Iter = 8750----------
# Loss = 7.851857
# Variable usage = 39.00%
# ----------Iter = 8800----------
# Loss = 7.837695
# Variable usage = 39.00%
# ----------Iter = 8850----------
# Loss = 7.823719
# Variable usage = 39.00%
# ----------Iter = 8900----------
# Loss = 7.809933
# Variable usage = 39.00%
# ----------Iter = 8950----------
# Loss = 7.936016
# Variable usage = 43.00%
# ----------Iter = 9000----------
# Loss = 7.785493
# Variable usage = 40.00%
# ----------Iter = 9050----------
# Loss = 7.771989
# Variable usage = 40.00%
# ----------Iter = 9100----------
# Loss = 7.758762
# Variable usage = 40.00%
# ----------Iter = 9150----------
# Loss = 7.745685
# Variable usage = 40.00%
# ----------Iter = 9200----------
# Loss = 7.732755
# Variable usage = 40.00%
# ----------Iter = 9250----------
# Loss = 7.719971
# Variable usage = 41.00%
# ----------Iter = 9300----------
# Loss = 7.966493
# Variable usage = 48.00%
# ----------Iter = 9350----------
# Loss = 7.705663
# Variable usage = 40.00%
# ----------Iter = 9400----------
# Loss = 7.701431
# Variable usage = 40.00%
# ----------Iter = 9450----------
# Loss = 7.681624
# Variable usage = 40.00%
# ----------Iter = 9500----------
# Loss = 7.669035
# Variable usage = 40.00%
# ----------Iter = 9550----------
# Loss = 7.656709
# Variable usage = 40.00%
# ----------Iter = 9600----------
# Loss = 7.644566
# Variable usage = 40.00%
# ----------Iter = 9650----------
# Loss = 8.227935
# Variable usage = 45.00%
# ----------Iter = 9700----------
# Loss = 7.623837
# Variable usage = 40.00%
# ----------Iter = 9750----------
# Loss = 7.611672
# Variable usage = 40.00%
# ----------Iter = 9800----------
# Loss = 7.609344
# Variable usage = 41.00%
# ----------Iter = 9850----------
# Loss = 7.591977
# Variable usage = 40.00%
# ----------Iter = 9900----------
# Loss = 7.579659
# Variable usage = 40.00%
# ----------Iter = 9950----------
# Loss = 7.568219
# Variable usage = 40.00%
# ----------Iter = 10000----------
# Loss = 8.138625
# Variable usage = 45.00%
# ----------Iter = 10050----------
# Loss = 7.548882
# Variable usage = 40.00%
# ----------Iter = 10100----------
# Loss = 7.537557
# Variable usage = 40.00%
# ----------Iter = 10150----------
# Loss = 8.883936
# Variable usage = 46.00%
# ----------Iter = 10200----------
# Loss = 7.522812
# Variable usage = 40.00%
# ----------Iter = 10250----------
# Loss = 9.983701
# Variable usage = 46.00%
# ----------Iter = 10300----------
# Loss = 7.502403
# Variable usage = 40.00%
# ----------Iter = 10350----------
# Loss = 7.671078
# Variable usage = 43.00%
# ----------Iter = 10400----------
# Loss = 7.483671
# Variable usage = 40.00%
# ----------Iter = 10450----------
# Loss = 7.475357
# Variable usage = 41.00%
# ----------Iter = 10500----------
# Loss = 7.488562
# Variable usage = 43.00%
# ----------Iter = 10550----------
# Loss = 7.457040
# Variable usage = 41.00%
# ----------Iter = 10600----------
# Loss = 7.446362
# Variable usage = 41.00%
# ----------Iter = 10650----------
# Loss = 7.436339
# Variable usage = 41.00%
# ----------Iter = 10700----------
# Loss = 7.499008
# Variable usage = 43.00%
# ----------Iter = 10750----------
# Loss = 7.418945
# Variable usage = 41.00%
# ----------Iter = 10800----------
# Loss = 7.548792
# Variable usage = 45.00%
# ----------Iter = 10850----------
# Loss = 7.405380
# Variable usage = 41.00%
# ----------Iter = 10900----------
# Loss = 7.394386
# Variable usage = 41.00%
# ----------Iter = 10950----------
# Loss = 7.386026
# Variable usage = 41.00%
# ----------Iter = 11000----------
# Loss = 7.405403
# Variable usage = 41.00%
# ----------Iter = 11050----------
# Loss = 7.373913
# Variable usage = 41.00%
# ----------Iter = 11100----------
# Loss = 7.394958
# Variable usage = 45.00%
# ----------Iter = 11150----------
# Loss = 7.361997
# Variable usage = 41.00%
# ----------Iter = 11200----------
# Loss = 7.350237
# Variable usage = 40.00%
# ----------Iter = 11250----------
# Loss = 9.795626
# Variable usage = 46.00%
# ----------Iter = 11300----------
# Loss = 7.334698
# Variable usage = 39.00%
# ----------Iter = 11350----------
# Loss = 7.697855
# Variable usage = 49.00%
# ----------Iter = 11400----------
# Loss = 7.321105
# Variable usage = 40.00%
# ----------Iter = 11450----------
# Loss = 7.311542
# Variable usage = 40.00%
# ----------Iter = 11500----------
# Loss = 7.302505
# Variable usage = 41.00%
# ----------Iter = 11550----------
# Loss = 7.358962
# Variable usage = 43.00%
# ----------Iter = 11600----------
# Loss = 7.312974
# Variable usage = 44.00%
# ----------Iter = 11650----------
# Loss = 7.293465
# Variable usage = 40.00%
# ----------Iter = 11700----------
# Loss = 7.290322
# Variable usage = 42.00%
# ----------Iter = 11750----------
# Loss = 7.271222
# Variable usage = 40.00%
# ----------Iter = 11800----------
# Loss = 7.262245
# Variable usage = 42.00%
# ----------Iter = 11850----------
# Loss = 7.288564
# Variable usage = 45.00%
# ----------Iter = 11900----------
# Loss = 7.248212
# Variable usage = 42.00%
# ----------Iter = 11950----------
# Loss = 7.240243
# Variable usage = 41.00%
# ----------Iter = 12000----------
# Loss = 7.298287
# Variable usage = 44.00%
# ----------Iter = 12050----------
# Loss = 7.921538
# Variable usage = 46.00%
# ----------Iter = 12100----------
# Loss = 7.302110
# Variable usage = 44.00%
# ----------Iter = 12150----------
# Loss = 7.217327
# Variable usage = 40.00%
# ----------Iter = 12200----------
# Loss = 7.214007
# Variable usage = 41.00%
# ----------Iter = 12250----------
# Loss = 7.202975
# Variable usage = 41.00%
# ----------Iter = 12300----------
# Loss = 7.238354
# Variable usage = 45.00%
# ----------Iter = 12350----------
# Loss = 7.324722
# Variable usage = 48.00%
# ----------Iter = 12400----------
# Loss = 7.191307
# Variable usage = 41.00%
# ----------Iter = 12450----------
# Loss = 7.181169
# Variable usage = 41.00%
# ----------Iter = 12500----------
# Loss = 7.172841
# Variable usage = 41.00%
# ----------Iter = 12550----------
# Loss = 7.164934
# Variable usage = 42.00%
# ----------Iter = 12600----------
# Loss = 7.172006
# Variable usage = 42.00%
# ----------Iter = 12650----------
# Loss = 7.311550
# Variable usage = 45.00%
# ----------Iter = 12700----------
# Loss = 7.149194
# Variable usage = 41.00%
# ----------Iter = 12750----------
# Loss = 7.142648
# Variable usage = 41.00%
# ----------Iter = 12800----------
# Loss = 8.607821
# Variable usage = 46.00%
# ----------Iter = 12850----------
# Loss = 7.137431
# Variable usage = 40.00%
# ----------Iter = 12900----------
# Loss = 7.126779
# Variable usage = 42.00%
# ----------Iter = 12950----------
# Loss = 7.124042
# Variable usage = 40.00%
# ----------Iter = 13000----------
# Loss = 7.119015
# Variable usage = 41.00%
# ----------Iter = 13050----------
# Loss = 7.115692
# Variable usage = 42.00%
# ----------Iter = 13100----------
# Loss = 7.111754
# Variable usage = 42.00%
# ----------Iter = 13150----------
# Loss = 7.099172
# Variable usage = 41.00%
# ----------Iter = 13200----------
# Loss = 10.786986
# Variable usage = 47.00%
# ----------Iter = 13250----------
# Loss = 7.087904
# Variable usage = 42.00%
# ----------Iter = 13300----------
# Loss = 7.097775
# Variable usage = 43.00%
# ----------Iter = 13350----------
# Loss = 7.128720
# Variable usage = 45.00%
# ----------Iter = 13400----------
# Loss = 7.073402
# Variable usage = 41.00%
# ----------Iter = 13450----------
# Loss = 7.304124
# Variable usage = 47.00%
# ----------Iter = 13500----------
# Loss = 7.108652
# Variable usage = 43.00%
# ----------Iter = 13550----------
# Loss = 7.382516
# Variable usage = 46.00%
# ----------Iter = 13600----------
# Loss = 7.056608
# Variable usage = 42.00%
# ----------Iter = 13650----------
# Loss = 7.051216
# Variable usage = 41.00%
# ----------Iter = 13700----------
# Loss = 7.429850
# Variable usage = 45.00%
# ----------Iter = 13750----------
# Loss = 7.058815
# Variable usage = 43.00%
# ----------Iter = 13800----------
# Loss = 7.036951
# Variable usage = 41.00%
# ----------Iter = 13850----------
# Loss = 8.446712
# Variable usage = 47.00%
# ----------Iter = 13900----------
# Loss = 7.023393
# Variable usage = 42.00%
# ----------Iter = 13950----------
# Loss = 9.305690
# Variable usage = 48.00%
# ----------Iter = 14000----------
# Loss = 7.014197
# Variable usage = 42.00%
# ----------Iter = 14050----------
# Loss = 7.352623
# Variable usage = 49.00%
# ----------Iter = 14100----------
# Loss = 7.273503
# Variable usage = 46.00%
# ----------Iter = 14150----------
# Loss = 7.005127
# Variable usage = 40.00%
# ----------Iter = 14200----------
# Loss = 6.997502
# Variable usage = 41.00%
# ----------Iter = 14250----------
# Loss = 6.997375
# Variable usage = 40.00%
# ----------Iter = 14300----------
# Loss = 11.492991
# Variable usage = 53.00%
# ----------Iter = 14350----------
# Loss = 7.093541
# Variable usage = 47.00%
# ----------Iter = 14400----------
# Loss = 7.164808
# Variable usage = 45.00%
# ----------Iter = 14450----------
# Loss = 6.981903
# Variable usage = 41.00%
# ----------Iter = 14500----------
# Loss = 6.976379
# Variable usage = 42.00%
# ----------Iter = 14550----------
# Loss = 6.972006
# Variable usage = 41.00%
# ----------Iter = 14600----------
# Loss = 7.010446
# Variable usage = 44.00%
# ----------Iter = 14650----------
# Loss = 6.985587
# Variable usage = 42.00%
# ----------Iter = 14700----------
# Loss = 6.956641
# Variable usage = 42.00%
# ----------Iter = 14750----------
# Loss = 8.920023
# Variable usage = 53.00%
# ----------Iter = 14800----------
# Loss = 6.958295
# Variable usage = 41.00%
# ----------Iter = 14850----------
# Loss = 7.381269
# Variable usage = 45.00%
# ----------Iter = 14900----------
# Loss = 6.948687
# Variable usage = 41.00%
# ----------Iter = 14950----------
# Loss = 6.943016
# Variable usage = 41.00%
# ----------Iter = 15000----------
# Loss = 6.933917
# Variable usage = 41.00%
# ----------Iter = 15050----------
# Loss = 6.927498
# Variable usage = 41.00%
# ----------Iter = 15100----------
# Loss = 6.952110
# Variable usage = 44.00%
# ----------Iter = 15150----------
# Loss = 9.490518
# Variable usage = 52.00%
# ----------Iter = 15200----------
# Loss = 6.932893
# Variable usage = 41.00%
# ----------Iter = 15250----------
# Loss = 6.927461
# Variable usage = 41.00%
# ----------Iter = 15300----------
# Loss = 6.914787
# Variable usage = 41.00%
# ----------Iter = 15350----------
# Loss = 6.912925
# Variable usage = 41.00%
# ----------Iter = 15400----------
# Loss = 7.010644
# Variable usage = 44.00%
# ----------Iter = 15450----------
# Loss = 6.898960
# Variable usage = 42.00%
# ----------Iter = 15500----------
# Loss = 6.903323
# Variable usage = 43.00%
# ----------Iter = 15550----------
# Loss = 6.906540
# Variable usage = 42.00%
# ----------Iter = 15600----------
# Loss = 7.242200
# Variable usage = 49.00%
# ----------Iter = 15650----------
# Loss = 6.891753
# Variable usage = 40.00%
# ----------Iter = 15700----------
# Loss = 6.888825
# Variable usage = 41.00%
# ----------Iter = 15750----------
# Loss = 6.985332
# Variable usage = 45.00%
# ----------Iter = 15800----------
# Loss = 6.921414
# Variable usage = 45.00%
# ----------Iter = 15850----------
# Loss = 6.886417
# Variable usage = 42.00%
# ----------Iter = 15900----------
# Loss = 6.874756
# Variable usage = 41.00%
# ----------Iter = 15950----------
# Loss = 6.867477
# Variable usage = 41.00%
# ----------Iter = 16000----------
# Loss = 6.868578
# Variable usage = 41.00%
# ----------Iter = 16050----------
# Loss = 6.953345
# Variable usage = 45.00%
# ----------Iter = 16100----------
# Loss = 6.857617
# Variable usage = 39.00%
# ----------Iter = 16150----------
# Loss = 7.707948
# Variable usage = 50.00%
# ----------Iter = 16200----------
# Loss = 6.863245
# Variable usage = 41.00%
# ----------Iter = 16250----------
# Loss = 6.855068
# Variable usage = 41.00%
# ----------Iter = 16300----------
# Loss = 6.931264
# Variable usage = 45.00%
# ----------Iter = 16350----------
# Loss = 7.218416
# Variable usage = 47.00%
# ----------Iter = 16400----------
# Loss = 6.942106
# Variable usage = 44.00%
# ----------Iter = 16450----------
# Loss = 7.095367
# Variable usage = 45.00%
# ----------Iter = 16500----------
# Loss = 6.851381
# Variable usage = 41.00%
# ----------Iter = 16550----------
# Loss = 6.880552
# Variable usage = 43.00%
# ----------Iter = 16600----------
# Loss = 6.880460
# Variable usage = 43.00%
# ----------Iter = 16650----------
# Loss = 6.824383
# Variable usage = 41.00%
# ----------Iter = 16700----------
# Loss = 6.826972
# Variable usage = 41.00%
# ----------Iter = 16750----------
# Loss = 6.814622
# Variable usage = 41.00%
# ----------Iter = 16800----------
# Loss = 7.511302
# Variable usage = 51.00%
# ----------Iter = 16850----------
# Loss = 7.816116
# Variable usage = 57.00%
# ----------Iter = 16900----------
# Loss = 7.062263
# Variable usage = 45.00%
# ----------Iter = 16950----------
# Loss = 6.830452
# Variable usage = 41.00%
# ----------Iter = 17000----------
# Loss = 6.808439
# Variable usage = 39.00%
# ----------Iter = 17050----------
# Loss = 8.420913
# Variable usage = 46.00%
# ----------Iter = 17100----------
# Loss = 6.797551
# Variable usage = 41.00%
# ----------Iter = 17150----------
# Loss = 7.213550
# Variable usage = 49.00%
# ----------Iter = 17200----------
# Loss = 6.828268
# Variable usage = 43.00%
# ----------Iter = 17250----------
# Loss = 9.173960
# Variable usage = 51.00%
# ----------Iter = 17300----------
# Loss = 6.810578
# Variable usage = 40.00%
# ----------Iter = 17350----------
# Loss = 6.789142
# Variable usage = 40.00%
# ----------Iter = 17400----------
# Loss = 6.780840
# Variable usage = 40.00%
# ----------Iter = 17450----------
# Loss = 8.471681
# Variable usage = 50.00%
# ----------Iter = 17500----------
# Loss = 9.022133
# Variable usage = 48.00%
# ----------Iter = 17550----------
# Loss = 6.943452
# Variable usage = 45.00%
# ----------Iter = 17600----------
# Loss = 6.778762
# Variable usage = 40.00%
# ----------Iter = 17650----------
# Loss = 10.780149
# Variable usage = 46.00%
# ----------Iter = 17700----------
# Loss = 6.767873
# Variable usage = 39.00%
# ----------Iter = 17750----------
# Loss = 8.243306
# Variable usage = 46.00%
# ----------Iter = 17800----------
# Loss = 6.762489
# Variable usage = 40.00%
# ----------Iter = 17850----------
# Loss = 7.872398
# Variable usage = 46.00%
# ----------Iter = 17900----------
# Loss = 6.759475
# Variable usage = 41.00%
# ----------Iter = 17950----------
# Loss = 7.275472
# Variable usage = 47.00%
# ----------Iter = 18000----------
# Loss = 7.251855
# Variable usage = 45.00%
# ----------Iter = 18050----------
# Loss = 6.766848
# Variable usage = 39.00%
# ----------Iter = 18100----------
# Loss = 7.412877
# Variable usage = 47.00%
# ----------Iter = 18150----------
# Loss = 7.290802
# Variable usage = 50.00%
# Stopping early

# %%
# Loss function plot
plt.figure(figsize=(8, 5))
plt.plot(50 * np.arange(len(train_loss_list)), train_loss_list)
plt.title('cLSTM training')
plt.ylabel('Loss')
plt.xlabel('Training steps')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Loss function plot
#       2 plt.figure(figsize=(8, 5))
# ----> 3 plt.plot(50 * np.arange(len(train_loss_list)), train_loss_list)
#       4 plt.title('cLSTM training')
#       5 plt.ylabel('Loss')
#
# File /usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_base.py:494, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     492 if len(xy) == 2:
#     493     x = _check_1d(xy[0])
# --> 494     y = _check_1d(xy[1])
#     495 else:
#     496     x, y = index_of(xy[-1])
#
# File /usr/local/lib/python3.9/dist-packages/matplotlib/cbook/__init__.py:1348, in _check_1d(x)
#    1342 # plot requires `shape` and `ndim`.  If passed an
#    1343 # object that doesn't provide them, then force to numpy array.
#    1344 # Note this will strip unit information.
#    1345 if (not hasattr(x, 'shape') or
#    1346         not hasattr(x, 'ndim') or
#    1347         len(x.shape) < 1):
# -> 1348     return np.atleast_1d(x)
#    1349 else:
#    1350     return x
#
# File <__array_function__ internals>:180, in atleast_1d(*args, **kwargs)
#
# File /usr/local/lib/python3.9/dist-packages/numpy/core/shape_base.py:65, in atleast_1d(*arys)
#      63 res = []
#      64 for ary in arys:
# ---> 65     ary = asanyarray(ary)
#      66     if ary.ndim == 0:
#      67         result = ary.reshape(1)
#
# File /usr/local/lib/python3.9/dist-packages/torch/_tensor.py:956, in Tensor.__array__(self, dtype)
#     954     return handle_torch_function(Tensor.__array__, (self,), self, dtype=dtype)
#     955 if dtype is None:
# --> 956     return self.numpy()
#     957 else:
#     958     return self.numpy().astype(dtype, copy=False)
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %%
# Check learned Granger causality
GC_est = clstm.GC().cpu().data.numpy()

print('True variable usage = %.2f%%' % (100 * np.mean(GC)))
print('Estimated variable usage = %.2f%%' % (100 * np.mean(GC_est)))
print('Accuracy = %.2f%%' % (100 * np.mean(GC == GC_est)))

# Make figures
fig, axarr = plt.subplots(1, 2, figsize=(10, 5))
axarr[0].imshow(GC, cmap='Blues')
axarr[0].set_title('GC actual')
axarr[0].set_ylabel('Affected series')
axarr[0].set_xlabel('Causal series')
axarr[0].set_xticks([])
axarr[0].set_yticks([])

axarr[1].imshow(GC_est, cmap='Blues', vmin=0, vmax=1, extent=(0, len(GC_est), len(GC_est), 0))
axarr[1].set_ylabel('Affected series')
axarr[1].set_xlabel('Causal series')
axarr[1].set_xticks([])
axarr[1].set_yticks([])

# Mark disagreements
for i in range(len(GC_est)):
    for j in range(len(GC_est)):
        if GC[i, j] != GC_est[i, j]:
            rect = plt.Rectangle((j, i-0.05), 1, 1, facecolor='none', edgecolor='red', linewidth=1)
            axarr[1].add_patch(rect)

plt.show()
# Out:
# True variable usage = 40.00%
# Estimated variable usage = 41.00%
# Accuracy = 97.00%
